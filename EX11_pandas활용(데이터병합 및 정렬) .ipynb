# %% [markdown]
# ### 학습목표
# - 목표에 맞게 데이터를 준비하고 다듬는 방법을 알아보자!

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd

# %%
#2. 데이터 불러오기!

import chardet

with open('./data/월급_급여/hr-pay-info-4월.csv','rb') as f:
    data = f.read()

chardet.detect(data)
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
df1 = pd.read_csv('./data/월급_급여/hr-pay-info-4월.csv',encoding = 'EUC-KR')

df2 = pd.read_csv('./data/월급_급여/hr-pay-info-5월.csv',encoding = 'EUC-KR')

df3 = pd.read_csv('./data/월급_급여/hr-pay-info-6월.csv',encoding = 'EUC-KR')

# %%
#3. 데이터 정보확인하기
df1
# Out:
#         EID  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT
# 0    E00206    20240401           월급             850
# 1    E00181    20240401           월급             791
# 2    E00164    20240401           월급             758
# 3    E00190    20240401           월급             708
# 4    E00209    20240401           월급             716
# ..      ...         ...          ...             ...
# 448  E00322    20240401          상여금             300
# 449  E00389    20240401          상여금             300
# 450  E00438    20240401          상여금             300
# 451  E00304    20240401          상여금             300
# 452  E00428    20240401          상여금             300
#
# [453 rows x 4 columns]

# %%
df2
# Out:
#         EID  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT
# 0    E00206    20240501           월급             850
# 1    E00181    20240501           월급             791
# 2    E00164    20240501           월급             758
# 3    E00190    20240501           월급             708
# 4    E00209    20240501           월급             716
# ..      ...         ...          ...             ...
# 146  E00322    20240501           월급             375
# 147  E00389    20240501           월급             375
# 148  E00438    20240501           월급             375
# 149  E00304    20240501           월급             375
# 150  E00428    20240501           월급             375
#
# [151 rows x 4 columns]

# %%
df3
# Out:
#         EID  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT
# 0    E00206    20240601           월급             850
# 1    E00181    20240601           월급             791
# 2    E00164    20240601           월급             758
# 3    E00190    20240601           월급             708
# 4    E00209    20240601           월급             716
# ..      ...         ...          ...             ...
# 146  E00322    20240601           월급             375
# 147  E00389    20240601           월급             375
# 148  E00438    20240601           월급             375
# 149  E00304    20240601           월급             375
# 150  E00428    20240601           월급             375
#
# [151 rows x 4 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EID             453 non-null    object
#  1   PAYMENT_DY      453 non-null    int64
#  2   PAYMENT_DVCD    453 non-null    object
#  3   PAYMENT_AMOUNT  453 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 14.3+ KB

# %% [markdown]
# ### DataFrame 병합하기(합치기) -> concat
# - pd.concat([df1, df2, df3,...,] axis = 0 or 1)
#   - 축설정
#   - axis = 0 : 행방향으로 병합 (위에서 아래 방향으로 병합)
#   - axis = 1 : 열방향으로 병합 (왼쪽에서 오른쪽 방향으로 병합)
#   - default값은 axis = 0

# %%
a = pd.concat([df1,df2,df3],axis = 0)

a

#axis = 0은 생략할수있다 생략하면 디폴트값은 axis = 0이다
#a = pd.concat([df1,df2,df3])
# Out:
#         EID  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT
# 0    E00206    20240401           월급             850
# 1    E00181    20240401           월급             791
# 2    E00164    20240401           월급             758
# 3    E00190    20240401           월급             708
# 4    E00209    20240401           월급             716
# ..      ...         ...          ...             ...
# 146  E00322    20240601           월급             375
# 147  E00389    20240601           월급             375
# 148  E00438    20240601           월급             375
# 149  E00304    20240601           월급             375
# 150  E00428    20240601           월급             375
#
# [755 rows x 4 columns]

# %%
b = pd.concat([df1,df2,df3],axis = 1, join = 'inner')

b
# Out:
#         EID  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT     EID  PAYMENT_DY  \
# 0    E00206    20240401           월급             850  E00206    20240501
# 1    E00181    20240401           월급             791  E00181    20240501
# 2    E00164    20240401           월급             758  E00164    20240501
# 3    E00190    20240401           월급             708  E00190    20240501
# 4    E00209    20240401           월급             716  E00209    20240501
# ..      ...         ...          ...             ...     ...         ...
# 146  E00322    20240401           월급             375  E00322    20240501
# 147  E00389    20240401           월급             375  E00389    20240501
# 148  E00438    20240401           월급             375  E00438    20240501
# 149  E00304    20240401           월급             375  E00304    20240501
# 150  E00428    20240401           월급             375  E00428    20240501
#
#     PAYMENT_DVCD  PAYMENT_AMOUNT     EID  PAYMENT_DY PAYMENT_DVCD  \
# ...

# %%
#행단위로 병합한 결과 -> csv로 저장

total_df = pd.concat([df1,df2,df3],axis = 0)

# total_df.to_csv('저장할 경로/파일명.csv')


total_df.to_csv('./data/월급_급여/total_pay_info.csv',index = False)

# %%
#우리가 만든 csv파일 가져오기

hr_pay_info = pd.read_csv('./data/월급_급여/total_pay_info.csv')

# %%
hr_pay_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 hr_pay_info
#
# NameError: name 'hr_pay_info' is not defined

# %%
with open('./data/월급_급여/org-info.csv','rb') as f:
    data = f.read()

chardet.detect(data)
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
org_info = pd.read_csv('./data/월급_급여/org-info.csv',encoding = 'EUC-KR',index_col = 'ORG_CD')

# %%
org_info
# Out:
#                                      ENG_DIVISION KOR_DIVISION  \
# ORG_CD
# ORG001                Home Entertainment Division       HE사업본부
# ORG002                Home Entertainment Division       HE사업본부
# ORG003                Home Entertainment Division       HE사업본부
# ORG004                Home Entertainment Division       HE사업본부
# ORG005                Home Entertainment Division       HE사업본부
# ORG006                Home Entertainment Division       HE사업본부
# ORG007                 Vehicle Solutions Division       VS사업본부
# ORG008                 Vehicle Solutions Division       VS사업본부
# ORG009                 Vehicle Solutions Division       VS사업본부
# ORG010                 Vehicle Solutions Division       VS사업본부
# ORG011                 Vehicle Solutions Division       VS사업본부
# ORG012                 Vehicle Solutions Division       VS사업본부
# ORG013   Home Appliance and Air Solution Division       HA사업본부
# ORG014   Home Appliance and Air Solution Division       HA사업본부
# ...

# %%
# data.info()
org_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, ORG001 to ORG030
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ENG_DIVISION    30 non-null     object
#  1   KOR_DIVISION    30 non-null     object
#  2   ENG_DEPARTMENT  30 non-null     object
#  3   KOR_DEPARTMENT  30 non-null     object
#  4   Team            30 non-null     object
#  5   KOR_TEAM        30 non-null     object
#  6   Role            30 non-null     object
# dtypes: object(7)
# memory usage: 1.9+ KB

# %%
org_info.shape
# Out:
# (30, 7)

# %%
hr_info = pd.read_csv('./data/hr-info.csv',encoding = 'EUC-KR')
# 연봉,성별,나이등 병합하면 구할수있음

# %%
org_agg = hr_info.groupby('ORG_CD').agg({
    'EID' : 'count',
    'AGE' : 'mean',
    'SERVICE_YEAR' : 'mean',
    'SALARY': 'mean'
}).round(2)

org_agg
# Out:
#         EID    AGE  SERVICE_YEAR   SALARY
# ORG_CD
# ORG001    6  26.17          0.33  5033.33
# ORG002    4  34.00          7.50  6550.00
# ORG003    5  34.60          7.60  6480.00
# ORG004   11  35.18          7.00  6445.45
# ORG005    8  29.25          2.00  5525.00
# ORG006    6  30.83          4.17  5966.67
# ORG007    7  36.71          8.00  6728.57
# ORG008    5  32.40          5.20  6020.00
# ORG009    5  29.80          2.20  5520.00
# ORG010    3  33.33          5.67  6300.00
# ORG011    5  37.40          8.40  6660.00
# ORG012    5  29.60          2.60  5680.00
# ORG013    8  32.62          3.62  5950.00
# ORG014    8  32.75          5.00  6025.00
# ORG015    3  24.67          0.00  5000.00
# ORG016    8  35.00          7.25  6500.00
# ORG017   10  29.40          2.70  5520.00
# ORG018    6  30.33          3.00  5716.67
# ORG019   10  29.30          2.40  5440.00
# ORG020    3  26.33          0.33  5066.67
# ORG021   12  34.25          6.67  6400.00
# ...

# %%
#hr_info 데이터 프레임에서'ORG_CD'조작코드에 따른 -> 인원수, 평균나이, 평균근속년수, 평균연봉 확인해보기!!
# org_info 한테 주자!
org_agg = hr_info.groupby('ORG_CD').agg({
    'EID' : 'count',
    'AGE' : 'mean',
    'SERVICE_YEAR' : 'mean',
    'SALARY': 'mean'
}).round(2)


# 컬럼이름을 수치에 맞게 변경
# 'HEAD_COUNT','AGE_MEAN','SERVICE_MEAN','SALARY_MEAN'

org_agg.columns = ['HEAD_COUNT','AGE_MEAN','SERVICE_MEAN','SALARY_MEAN']

org_agg
# Out:
#         HEAD_COUNT  AGE_MEAN  SERVICE_MEAN  SALARY_MEAN
# ORG_CD
# ORG001           6     26.17          0.33      5033.33
# ORG002           4     34.00          7.50      6550.00
# ORG003           5     34.60          7.60      6480.00
# ORG004          11     35.18          7.00      6445.45
# ORG005           8     29.25          2.00      5525.00
# ORG006           6     30.83          4.17      5966.67
# ORG007           7     36.71          8.00      6728.57
# ORG008           5     32.40          5.20      6020.00
# ORG009           5     29.80          2.20      5520.00
# ORG010           3     33.33          5.67      6300.00
# ORG011           5     37.40          8.40      6660.00
# ORG012           5     29.60          2.60      5680.00
# ORG013           8     32.62          3.62      5950.00
# ORG014           8     32.75          5.00      6025.00
# ORG015           3     24.67          0.00      5000.00
# ORG016           8     35.00          7.25      6500.00
# ...

# %%
# org_info -> org_agg 병합

# %%
pd.merge(org_info,org_agg, on = 'ORG_CD')
# Out:
#                                      ENG_DIVISION KOR_DIVISION  \
# ORG_CD
# ORG001                Home Entertainment Division       HE사업본부
# ORG002                Home Entertainment Division       HE사업본부
# ORG003                Home Entertainment Division       HE사업본부
# ORG004                Home Entertainment Division       HE사업본부
# ORG005                Home Entertainment Division       HE사업본부
# ORG006                Home Entertainment Division       HE사업본부
# ORG007                 Vehicle Solutions Division       VS사업본부
# ORG008                 Vehicle Solutions Division       VS사업본부
# ORG009                 Vehicle Solutions Division       VS사업본부
# ORG010                 Vehicle Solutions Division       VS사업본부
# ORG011                 Vehicle Solutions Division       VS사업본부
# ORG012                 Vehicle Solutions Division       VS사업본부
# ORG013   Home Appliance and Air Solution Division       HA사업본부
# ORG014   Home Appliance and Air Solution Division       HA사업본부
# ...

# %%
org_info_result =pd.concat([org_info,org_agg],axis = 0, join = "inner")  # 행은 컬럼 기준으로 합쳐지는건데 겹치는 컬럼이 없기 때문에 나오지않는다.

org_info_result
# Out:
# Empty DataFrame
# Columns: []
# Index: [ORG001, ORG002, ORG003, ORG004, ORG005, ORG006, ORG007, ORG008, ORG009, ORG010, ORG011, ORG012, ORG013, ORG014, ORG015, ORG016, ORG017, ORG018, ORG019, ORG020, ORG021, ORG022, ORG023, ORG024, ORG025, ORG026, ORG027, ORG028, ORG029, ORG030, ORG001, ORG002, ORG003, ORG004, ORG005, ORG006, ORG007, ORG008, ORG009, ORG010, ORG011, ORG012, ORG013, ORG014, ORG015, ORG016, ORG017, ORG018, ORG019, ORG020, ORG021, ORG022, ORG023, ORG024, ORG025, ORG026, ORG027, ORG028, ORG029, ORG030]

# %%
org_agg.head(1)
# Out:
#         HEAD_COUNT  AGE_MEAN  SERVICE_MEAN  SALARY_MEAN
# ORG_CD
# ORG001           6     26.17          0.33      5033.33

# %%
org_info.head(1)
# Out:
#                        ENG_DIVISION KOR_DIVISION  \
# ORG_CD
# ORG001  Home Entertainment Division       HE사업본부
#
#                            ENG_DEPARTMENT KOR_DEPARTMENT  \
# ORG_CD
# ORG001  TV Business Operations Department       TV사업운영센터
#
#                               Team    KOR_TEAM  \
# ORG_CD
# ORG001  TV Product Management Team  TV 제품 관리 팀
#
#                                                Role
# ORG_CD
# ORG001  관리 및 마케팅 전략 수립을 통해 TV 제품의 전체 라이프사이클을 관리합니다.

# %% [markdown]
# ![image.png](attachment:b14b809b-65ed-492e-bffa-555a7b803dc2.png)

# %% [markdown]
# ![image.png](attachment:16db2c25-be90-498c-a9ab-511e0ce66600.png)

# %%
# concat은 인덱스가 같으면 병합할때 인덱스를 합쳐서 붙힌다 ex) 위에것을 병합하면 0 민지 90 이런식으로 병합함

# %% [markdown]
# ### DataFrame 병합 (합치기) - Merge
# - 두개의 DataFrame 에서 공통된 키값을 기준으로 병합
# - 데이터의 정보를 기준으로 병합 -> 두개의 DataFrame 에 공통으로 존재
#
# - Merge 특징
#   - Join 속성
#     - inner: 교집합 병합 (기본) -> 둘 다 있는 값만 보여줌
#     - outer: 합집합 병합
#     - left: 왼쪽 데이터프레임 기준
#     - right: 오른쪽 데이터프레임 기준

# %% [markdown]
# ### Concat, Merge 차이점
# - concat
#   - 병합기준: 인덱스명, 컬럼명
#   - 단순연결 (행추가, 열추가)
# - merge
#   - 병합기준: 데이터값 (공통된 키값)
#   - 데이터셋 간의 관계를 바탕으로 결합

# %%
hr_pay_info
# Out:
#         EID  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT
# 0    E00206    20240401           월급             850
# 1    E00181    20240401           월급             791
# 2    E00164    20240401           월급             758
# 3    E00190    20240401           월급             708
# 4    E00209    20240401           월급             716
# ..      ...         ...          ...             ...
# 750  E00322    20240601           월급             375
# 751  E00389    20240601           월급             375
# 752  E00438    20240601           월급             375
# 753  E00304    20240601           월급             375
# 754  E00428    20240601           월급             375
#
# [755 rows x 4 columns]

# %%
hr_info
# Out:
#         EID ENAME GENDER  ORG_CD POS_CD  AGE  SERVICE_YEAR EDU_LEVEL  \
# 0    E00206   시이오      M     NaN   P001   49            25     박사 학위
# 1    E00181   나사장      F     NaN   P002   49            24     박사 학위
# 2    E00164  난부사장      M     NaN   P003   48            22     박사 학위
# 3    E00190   판라다      F  ORG007   P004   47            18     박사 학위
# 4    E00209   누훈봉      M  ORG023   P004   47            19     박사 학위
# ..      ...   ...    ...     ...    ...  ...           ...       ...
# 195  E00322   부탐회      F  ORG014   P009   23             0     학사 학위
# 196  E00389   초두반      F  ORG012   P009   23             0     학사 학위
# 197  E00438   권개득      M  ORG024   P009   23             0     학사 학위
# 198  E00304   탐출조      M  ORG009   P009   24             0     학사 학위
# 199  E00428   을충나      F  ORG003   P009   24             0     학사 학위
#
#      PERFORMANCE_SCORE  SALARY LAST_PROMO_DT  TRAINING_HOURS  \
# 0                 4.50   10200    2024-03-01             240
# ...

# %% [markdown]
# - 상황 : hr_pay_info 데이터프레임에 직원번호(EID)는 있는데 이름이(ENAME) 없어서 누군지 모르겠다. 그럼 이름이 들어있는 데이터프레임에서 직원번호(EID)를 기준으로 찾아와서 붙여야 한다.
# - hr_info, hr_pay_info 두개의 DataFrame 을 통해 직원별 급여내역 정리

# %%
#hr_info에서 필요한 컬럼만 추출
# EID, ENAME GENDER 

EEG = hr_info[["EID","ENAME","GENDER"]]

#병합 진행
#pd.merge(df1,df2, on ='병합 기준이 되는 컬럼명',how = 'join방식')
# 병합은 기준이 되는 데이터로 한다. 왼쪽은 left 오른쪽은 right다

#병합은 기준이 된 셀에다가 갖다 붙히는것이다. 서로 행 갯수가 맞지않는다면 행이 넘치는만큼 NULL값이 뜬다. 만약 행이 더 적다면 남는 행은 생략된채로 병합이된다.


a = pd.merge(EEG,hr_pay_info, on = "EID",how = 'left')
a
# Out:
#         EID ENAME GENDER  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT
# 0    E00206   시이오      M  20240401.0           월급           850.0
# 1    E00206   시이오      M  20240401.0          성과급           425.0
# 2    E00206   시이오      M  20240401.0          상여금           300.0
# 3    E00206   시이오      M  20240501.0           월급           850.0
# 4    E00206   시이오      M  20240601.0           월급           850.0
# ..      ...   ...    ...         ...          ...             ...
# 799  E00428   을충나      F  20240401.0           월급           375.0
# 800  E00428   을충나      F  20240401.0          성과급           188.0
# 801  E00428   을충나      F  20240401.0          상여금           300.0
# 802  E00428   을충나      F  20240501.0           월급           375.0
# 803  E00428   을충나      F  20240601.0           월급           375.0
#
# [804 rows x 6 columns]

# %%
a.iloc[400:405, : ]
# Out:
#         EID  PAYMENT_DY PAYMENT_DVCD  PAYMENT_AMOUNT ENAME GENDER
# 400  E00479    20240401          상여금             300   감우푸      F
# 401  E00173    20240401          상여금             300   휴룡로      M
# 402  E00182    20240401          상여금             300   장내영      F
# 403  E00197    20240401          상여금             300   홍민두      M
# 404  E00212    20240401          상여금             300   환국준      M

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755 entries, 0 to 754
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EID             755 non-null    object
#  1   ENAME           755 non-null    object
#  2   GENDER          755 non-null    object
#  3   PAYMENT_DY      755 non-null    int64
#  4   PAYMENT_DVCD    755 non-null    object
#  5   PAYMENT_AMOUNT  755 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 35.5+ KB

# %% [markdown]
# ### 정리
# - hr_info_df, hr_pay_info
# - leftjoin: 조직 구성원 목록을 기준으로 병합, 급여정보가 없는 구성원도 포함
# - rightjoin: 급여 지급데이터 기준으로 병합, 급여정보가 없는 구성원은 제외
# - 조인방식은 분석 목적에 따라 다르게 선택
# - 구성원전체를 유지 left, 급여내역중심의 정리 right

# %% [markdown]
# ### 데이터 삭제
# - df.drop('삭제하고자하는 인덱스or컬럼명 작성',axis = 0 or 1)
# - 행삭제 -> axis 0 , 열삭제 -> axis 1

# %%
# drop 기본 축 -> (행기준 axis=0)

# %%
hr_info.drop('NATION') # 'NATION'은 열이니까 삭제할거면 axis = 1 이라고 해야한다.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 hr_info.drop('NATION')
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
hr_info.drop('NATION', axis =1) #drop은 삭제해서 보여주는것, 본 데이터에 영향을 미치진않는다 ( hr_info에 NATION이 삭제된건아님)
# Out:
#         EID ENAME GENDER  ORG_CD POS_CD  AGE  SERVICE_YEAR EDU_LEVEL  \
# 0    E00206   시이오      M     NaN   P001   49            25     박사 학위
# 1    E00181   나사장      F     NaN   P002   49            24     박사 학위
# 2    E00164  난부사장      M     NaN   P003   48            22     박사 학위
# 3    E00190   판라다      F  ORG007   P004   47            18     박사 학위
# 4    E00209   누훈봉      M  ORG023   P004   47            19     박사 학위
# ..      ...   ...    ...     ...    ...  ...           ...       ...
# 195  E00322   부탐회      F  ORG014   P009   23             0     학사 학위
# 196  E00389   초두반      F  ORG012   P009   23             0     학사 학위
# 197  E00438   권개득      M  ORG024   P009   23             0     학사 학위
# 198  E00304   탐출조      M  ORG009   P009   24             0     학사 학위
# 199  E00428   을충나      F  ORG003   P009   24             0     학사 학위
#
#      PERFORMANCE_SCORE  SALARY LAST_PROMO_DT  TRAINING_HOURS  \
# 0                 4.50   10200    2024-03-01             240
# ...

# %%
#inplace 속성 -> 실행결과를 저장함
hr_info.drop('NATION', axis =1, inplace = True) #inplace는 NATION이라는 데이터를 삭제했다는것을 저장한다. (hr_info에 NATION이 삭제됨)

# %% [markdown]
# ### apply
# - DataFrame, Series 데이터에 함수를 행or열 단위로 적용할때 사용
# - 데이터명.apply(함수명, 축설정) -> 기본축은 행 우선
# - 예시 :
#       - s.apply(plus_ten)
#       - name.apply(add_nim)
#       - score.apply(pass_or_fail)

# %%
score = pd.Series([95,60,82,45,77])
score
# Out:
# 0    95
# 1    60
# 2    82
# 3    45
# 4    77
# dtype: int64

# %%
# 1단계) 함수 만들기
def pass_or_fail(x):
    if x>=70:
        return '합격'
    else:
        return '불합격'

# %%
# 2단계) apply 적용
score.apply(pass_or_fail)
# Out:
# 0     합격
# 1    불합격
# 2     합격
# 3    불합격
# 4     합격
# dtype: object

# %%
# 데이터프레임 실습
# 학생 점수 데이터
df = pd.DataFrame({
    '수학': [80, 90, 70],
    '영어': [75, 85, 95],
    '국어': [88, 92, 78],
},
    index = ['정경','성훈','강민'])

df
# Out:
#     수학  영어  국어
# 정경  80  75  88
# 성훈  90  85  92
# 강민  70  95  78

# %%
# 각 학생들의 평균점수
def avg_score(col):
    return col.mean()

# %%
# 2단계 apply적용

df.apply(avg_score, axis = 1)
# Out:
# 정경    81.0
# 성훈    89.0
# 강민    81.0
# dtype: float64
